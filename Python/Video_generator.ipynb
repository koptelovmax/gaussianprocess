# %% [markdown]
# # Sample video generator

# %%
import numpy as np
import matplotlib.pyplot as mp
from scipy import ndimage
import cv2
% matplotlib inline

# %%
def rotate_image(img,alpha):
    
    img_rot = ndimage.rotate(img,alpha,mode='nearest')
    h_new=img_rot.shape[0]
    w_new=img_rot.shape[1]
    y = int(w_new/2)-int(w/2)
    x = int(h_new/2)-int(h/2)
    img_crop = img_rot[x:x+h, y:y+w]
    
    return img_crop

# %%
def draw_rectangle(height,weight,w_rect,h_rect):
    
    x,y = 320,240
    img = np.zeros((height,weight,3), np.uint8)+255
    cv2.rectangle(img,(x,y),(x+w_rect,y+h_rect),(0,0,0),-1)
    
    return img

# %%
w,h = 640,480
pi = 3.14
f0 = 0.045
f1 = 0.0025

cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'DIB ')
out = cv2.VideoWriter('output.avi',fourcc, 25.0, (w,h))

for i in range(250):
    alpha = 2*pi*f0*i
    height = 4*30 #int(30*np.abs(np.sin(2*pi*f1*i)))
    img = draw_rectangle(h,w,4*10,height)
    frame = rotate_image(img,alpha)
    out.write(frame)
    print(frame.max())
    print(frame.min())

cap.release()
out.release()
cv2.destroyAllWindows()
print('Done!')
# Out:
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# 255
# 0
# ...

# %%
frame.greyscale()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-0c097994d2c3> in <module>()
# ----> 1 frame.greyscale()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'greyscale'
